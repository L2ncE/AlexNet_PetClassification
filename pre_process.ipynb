# %%
import os
import zipfile
from PIL import Image
import shutil

# Dataset name
DATASET_NAME = "PetImages"


class Dataset:
    # Image file extensions
    IMG_EXTENSIONS = ['.jpg', '.jpeg', '.png']

    def __init__(self, dataset_path):
        # Set dataset path
        self.dataset_path = dataset_path

    def is_image_file(self, filename):
        """Check if file is an image file with extensions defined in IMG_EXTENSIONS."""
        return any(filename.lower().endswith(extension) for extension in self.IMG_EXTENSIONS)

    def delete_file(self, img_path):
        """Delete file if it's an invalid image file."""
        if os.path.isdir(img_path):
            # Remove directory if it is empty
            os.rmdir(img_path)
        else:
            # Remove file if it exists and print message
            os.remove(img_path)
            print(f"Deleted invalid image file: {img_path}")

    def is_jpg(self, img_path):
        """Check if file is a JPEG file."""
        try:
            # Open image file
            i = Image.open(img_path)
            return i.format == 'JPEG'
        except IOError:
            return False

    def filter_dataset(self):
        """Filter dataset by deleting invalid image files."""
        for sub_dir in os.listdir(self.dataset_path):
            for file_name in os.listdir(os.path.join(self.dataset_path, sub_dir)):
                img_path = os.path.join(os.path.join(self.dataset_path, sub_dir, file_name))
                if not (self.is_image_file(file_name) and self.is_jpg(img_path)):
                    # Delete invalid image file
                    self.delete_file(img_path)
                    continue

    def make_dirs(self, path):
        """Create directory and its parent directories if they don't exist."""
        os.makedirs(path, exist_ok=True)

    def join_path(self, path, *paths):
        """Join paths."""
        return os.path.join(path, *paths)

    def split_dataset(self, eval_split=0.1):
        """Split dataset into train and evaluation sets."""
        self.make_dirs(self.join_path(self.dataset_path, "train"))
        self.make_dirs(self.join_path(self.dataset_path, "eval"))
        for sub_dir in os.listdir(self.dataset_path):
            if sub_dir in ["train", "eval"]:
                continue
            cls_list = os.listdir(self.join_path(self.dataset_path, sub_dir))
            train_size = int(len(cls_list) * (1 - eval_split))
            self.make_dirs(self.join_path(self.dataset_path, "train", sub_dir))
            self.make_dirs(self.join_path(self.dataset_path, "eval", sub_dir))
            for i, file_name in enumerate(os.listdir(self.join_path(self.dataset_path, sub_dir))):
                source_file = self.join_path(self.dataset_path, sub_dir, file_name)
                if i <= train_size:
                    target_file = self.join_path(self.dataset_path, "train", sub_dir, file_name)
                else:
                    target_file = self.join_path(self.dataset_path, "eval", sub_dir, file_name)
                shutil.move(source_file, target_file)
            # Delete directory after files have been moved
            self.delete_file(self.join_path(self.dataset_path, sub_dir))

    @staticmethod
    def extract_dataset(zip_file, save_dir):
        """Extract dataset from zip file to save directory."""
        if not os.path.exists(zip_file):
            raise ValueError(f"Zip file {zip_file} does not exist!")
        try:
            print(f"Extracting dataset from {zip_file} to {save_dir}")
            zip_file = zipfile.ZipFile(zip_file)
            for names in zip_file.namelist():
                zip_file.extract(names, save_dir)
            zip_file.close()
            print(f"Successfully extracted dataset at {Dataset.join_path(save_dir, DATASET_NAME)}")
        except:
            raise ValueError(f"Failed to extract dataset from {zip_file}!")


# Main function
if __name__ == '__main__':
    # Set save directory path
    save_dir = os.path.abspath("./dataset")
    # Create dataset directory if it doesn't exist
    Dataset(save_dir).make_dirs(save_dir)
    zip_file = "cat_dog.zip"
    # Extract dataset from zip file to save directory
    Dataset.extract_dataset(zip_file, save_dir)
    dataset = Dataset(os.path.join(save_dir, DATASET_NAME))
    # Filter dataset by deleting invalid image files
    dataset.filter_dataset()
    # Split dataset into train and evaluation sets
    dataset.split_dataset(eval_split=0.1)
# Out:
# Extracting dataset from cat_dog.zip to /home/ma-user/work/dataset
# Successfully extracted dataset at PetImages
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/4257.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/1356.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11233.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9367.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8693.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10158.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11702.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9188.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10797.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/12102.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10747.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8194.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10969.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10726.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10863.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/1866.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9640.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/4367.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6032.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8557.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/573.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8364.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/5263.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7128.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11912.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8563.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/5243.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6318.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/1017.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/1900.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/50.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/2905.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6059.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7969.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/Thumbs.db
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10972.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9851.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11166.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/3320.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/5955.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/3546.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/1308.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/4203.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7652.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/5604.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/3038.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/561.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7459.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6855.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11560.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/296.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/12289.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/3155.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6555.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/565.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/719.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/3885.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6718.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7718.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10383.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/4640.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8641.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11410.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/5618.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/4134.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7133.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/5730.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10351.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7739.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8730.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/2688.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/2353.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8889.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7743.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/1259.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/4924.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/2877.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6305.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10678.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9026.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7311.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11590.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/4086.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6213.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6238.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/543.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/2915.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/4301.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8521.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10173.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10705.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/1168.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9643.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/1884.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8715.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/5736.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/663.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9414.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9043.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/12114.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9556.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10353.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/522.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9967.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11253.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/2384.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/3288.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7514.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/8126.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/4654.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10907.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/414.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11675.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/5790.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7112.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6430.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9145.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11692.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9500.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/3136.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/2494.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10401.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/5547.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/3927.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/3588.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/5104.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/9961.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11853.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11849.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/2317.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/11285.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10733.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/2479.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/7369.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/10637.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6500.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Dog/6503.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/3967.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/10820.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/7003.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/10125.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/11095.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/11565.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/3161.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/11874.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/3300.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/1757.jpg
# /home/ma-user/anaconda3/envs/TensorFlow-2.1/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:850: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/1914.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4000.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/8470.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/7647.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4750.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/5614.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/8958.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/3649.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/6435.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/6768.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/6029.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/6900.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/9100.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/12080.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4874.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/9565.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/8415.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/10874.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/12269.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/7642.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/Thumbs.db
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/3491.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/6906.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/1386.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/1937.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/6376.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/6491.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/5553.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4821.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/3197.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/7845.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4629.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/1151.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/11935.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/3710.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/3153.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/9619.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4293.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/1267.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4833.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/2021.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/7502.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/9361.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4334.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/140.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/445.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/5370.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/2742.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/1936.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/10501.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/6486.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/10404.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/8553.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/23.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/6980.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/8832.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4351.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/8183.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/7978.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/2569.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/9208.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/11083.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/5077.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/11864.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/666.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/12235.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/9328.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/11729.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/391.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/8295.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4929.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/2663.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/10073.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/7968.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/4322.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/9171.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/910.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/11397.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/11210.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/5819.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/11086.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/2189.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/9778.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/936.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/850.jpg
# Deleted invalid image file: /home/ma-user/work/dataset/PetImages/Cat/660.jpg
